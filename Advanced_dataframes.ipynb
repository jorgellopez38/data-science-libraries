# %%
#EXERCISES 2

import pandas as pd
import numpy as np
from pydataset import data

# %%
#Copy the users and roles DataFrames from the examples above.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'jorge', 'mike', 'adam'],
    'role_id': [1, 2, 3, 3,  np.nan,  np.nan]

}) 
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4  jorge      3.0
# 4   5   mike      NaN
# 5   6   adam      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter'],
    
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
#What is the result of using a right join on the DataFrames?

users.merge(roles, 
            left_on='role_id', 
            right_on='id', 
            how='right', 
            
           )
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0  jorge      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %%
#What is the result of using an outer join on the DataFrames?

users.merge(roles, 
            left_on='role_id', 
            right_on='id', 
            how='outer', 
            
           )
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0  jorge      3.0   3.0   reviewer
# 4   5.0   mike      NaN   NaN        NaN
# 5   6.0   adam      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %%
#What happens if you drop the foreign keys from the DataFrames and try to merge them?

(users.merge(roles, 
            left_on='role_id', 
            right_on='id', 
            how='outer', 
            
           )
 .drop(columns='role_id'))
# Out:
#    id_x name_x  id_y     name_y
# 0   1.0    bob   1.0      admin
# 1   2.0    joe   2.0     author
# 2   3.0  sally   3.0   reviewer
# 3   4.0  jorge   3.0   reviewer
# 4   5.0   mike   NaN        NaN
# 5   6.0   adam   NaN        NaN
# 6   NaN    NaN   4.0  commenter

# %%
#Output and read the documentation for the mpg dataset.

mpg = data('mpg') 
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %%
#How many rows and columns are in the dataset?

mpg.shape
# Out:
# (234, 11)

# %%
#Check out your column names and perform any cleanup you may want on them.


mpg = mpg.rename(columns={'cty': 'city'}).rename(columns={'hwy': 'highway'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %%
#Display the summary statistics for the dataset.

mpg.describe()
# Out:
#             displ         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#How many different manufacturers are there?

#len(mpg.manufacturer.unique())
mpg['manufacturer'].nunique()
# Out:
# 15

# %%
#How many different models are there?

#len(mpg.model.unique())

mpg['model'].nunique()
# Out:
# 38

# %%
#Create a column named mileage_difference like you did in the DataFrames exercises; 
#this column should contain the difference between highway and city mileage for each car.

mpg['mileage_difference'] = mpg.highway - mpg.city
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# 3    compact                  11
# 4    compact                   9
# 5    compact                  10
# ..       ...                 ...
# 230  midsize                   9
# 231  midsize                   8
# 232  midsize                  10
# 233  midsize                   8
# 234  midsize                   9
#
# [234 rows x 12 columns]

# %%
#Create a column named average_mileage like you did in the DataFrames exercises; this is the mean
#of the city and highway mileage.

mpg['average_mileage'] = (mpg.city + mpg.highway) / 2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  average_mileage
# 1    compact             23.5
# 2    compact             25.0
# 3    compact             25.5
# 4    compact             25.5
# 5    compact             21.0
# ..       ...              ...
# 230  midsize             23.5
# 231  midsize             25.0
# 232  midsize             21.0
# 233  midsize             22.0
# 234  midsize             21.5
#
# [234 rows x 12 columns]

# %%
#Create a new column on the mpg dataset named is_automatic that holds boolean values denoting 
#whether the car has an automatic transmission.



mpg['is_automatic'] = mpg.trans.str.startswith('a')

mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  average_mileage  is_automatic
# 1    compact             23.5          True
# 2    compact             25.0         False
# 3    compact             25.5         False
# 4    compact             25.5          True
# 5    compact             21.0          True
# ..       ...              ...           ...
# 230  midsize             23.5          True
# 231  midsize             25.0         False
# 232  midsize             21.0          True
# 233  midsize             22.0         False
# 234  midsize             21.5          True
#
# [234 rows x 13 columns]

# %%
#Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

mpg.groupby('manufacturer')['average_mileage'].mean().nlargest(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %%
#Do automatic or manual cars have better miles per gallon?


mpg.groupby('is_automatic')['average_mileage'].mean()
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %%
##EXERCISES 1

import env
import os

# create the url variable (string) with my username, password and host inserted
url = f'mysql+pymysql://{username}:{password}@{host}/employees'

# %%
#Create a function named get_db_url. It should accept a username, hostname, password, and database name and 
#return a url connection string formatted like in the example at the start of this lesson.

def get_db_url(db, env_file=os.path.exists('env.py')):
    '''
    return a formatted string containing username, password, 
    host and database for connecting to the mySQL server
    and the database indicated.
    enc_file checks to see if the env.py exists in cwd
    '''
    if env_file:
        username, password, host = (env.username, env.password, env.host)
        return f'mysql+pymysql://{username}:{password}@{host}/{db}'
    else:
        return 'hello, you need a username and password to get in!'
    
url = get_db_url('employees')

# %%
query = 'SELECT * FROM employees LIMIT 10'

# %%
df = pd.read_sql(query, url)

# %%
#Use your function to obtain a connection to the employees database.



query = '''
SELECT
    emp_no,
    first_name,
    last_name
FROM employees
WHERE gender = 'F'
LIMIT 100;
'''

# %%
employees_df = pd.read_sql(query, url)
employees_df.head()
# Out:
#    emp_no first_name  last_name
# 0   10002    Bezalel     Simmel
# 1   10006     Anneke    Preusig
# 2   10007    Tzvetan  Zielinski
# 3   10009     Sumant       Peac
# 4   10010  Duangkaew   Piveteau

# %%
#Once you have successfully run a query:
#Intentionally make a typo in the database url. What kind of error message do you see?
#Intentionally make an error in your SQL query. What does the error message look like?



query = '''
SELECT
    emp_no,
    first_name,
    last_name
FROM employees
WHERE gender = 'F'
LIMIT 100;
'''

# %%
df = pd.read_sql(query, url)

# %%
employees_df = pd.read_sql(query, url)
employees_df.head()
# Out:
#    emp_no first_name  last_name
# 0   10002    Bezalel     Simmel
# 1   10006     Anneke    Preusig
# 2   10007    Tzvetan  Zielinski
# 3   10009     Sumant       Peac
# 4   10010  Duangkaew   Piveteau

# %%
#Read the employees and titles tables into two separate DataFrames.


query = '''
SELECT *
FROM employees
LIMIT 100;
'''

# %%
df = pd.read_sql(query, url)

# %%
employees_df = pd.read_sql(query, url)
employees_df.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
query = '''
SELECT *
FROM titles
LIMIT 100;
'''

# %%
df = pd.read_sql(query, url)

# %%
titles_df = pd.read_sql(query, url)
titles_df.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
#How many rows and columns do you have in each DataFrame? Is that what you expected?

titles_df.shape, employees_df.shape
# Out:
# ((100, 4), (100, 6))

# %%
#Display the summary statistics for each DataFrame.

titles_df.describe(), employees_df.describe()
# Out:
# (             emp_no
#  count    100.000000
#  mean   10034.320000
#  std       18.656859
#  min    10001.000000
#  25%    10018.000000
#  50%    10035.500000
#  75%    10050.000000
#  max    10066.000000,
#               emp_no
#  count    100.000000
#  mean   10050.500000
#  std       29.011492
#  min    10001.000000
#  25%    10025.750000
#  50%    10050.500000
#  75%    10075.250000
#  max    10100.000000)

# %%
#How many unique titles are in the titles DataFrame?

len(titles_df.title.unique())
# Out:
# 6

# %%
#What is the oldest date in the to_date column?

titles_df.sort_values('to_date').head(1)
# Out:
#     emp_no     title   from_date     to_date
# 71   10048  Engineer  1985-02-24  1987-01-27

# %%
#What is the most recent date in the to_date column?

titles_df.sort_values('to_date').tail(1)
# Out:
#     emp_no            title   from_date     to_date
# 49   10035  Senior Engineer  1996-09-05  9999-01-01

# %%
from env import host, username, password

url = f'mysql+pymysql://{username}:{password}@{host}/chipotle'

# %%
###EXERCISE 3

#Use your get_db_url function to help you explore the data from the chipotle database.

def get_db_url(db, env_file=os.path.exists('env.py')):
    '''
    return a formatted string containing username, password, 
    host and database for connecting to the mySQL server
    and the database indicated.
    enc_file checks to see if the env.py exists in cwd
    '''
    if env_file:
        username, password, host = (env.username, env.password, env.host)
        return f'mysql+pymysql://{username}:{password}@{host}/{db}'
    else:
        return 'hello, you need a username and password to get in!'
    
url = get_db_url('chipotle')

# %%
query = '''

SELECT *
FROM orders
LIMIT 100;
'''

# %%
df = pd.read_sql(query, url)

# %%
chipotle_df = pd.read_sql(query, url)
chipotle_df.head(20)
# Out:
#     id  order_id  quantity                              item_name  \
# 0    1         1         1           Chips and Fresh Tomato Salsa
# 1    2         1         1                                   Izze
# 2    3         1         1                       Nantucket Nectar
# 3    4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4    5         2         2                           Chicken Bowl
# 5    6         3         1                           Chicken Bowl
# 6    7         3         1                          Side of Chips
# 7    8         4         1                          Steak Burrito
# 8    9         4         1                       Steak Soft Tacos
# 9   10         5         1                          Steak Burrito
# 10  11         5         1                    Chips and Guacamole
# 11  12         6         1                   Chicken Crispy Tacos
# 12  13         6         1                     Chicken Soft Tacos
# 13  14         7         1                           Chicken Bowl
# 14  15         7         1                    Chips and Guacamole
# 15  16         8         1  Chips and Tomatillo-Green Chili Salsa
# 16  17         8         1                        Chicken Burrito
# 17  18         9         1                        Chicken Burrito
# 18  19         9         2                            Canned Soda
# 19  20        10         1                           Chicken Bowl
#
#                                                                            choice_description  \
# 0                                                                                         nan
# 1                                                                                [Clementine]
# 2                                                                                     [Apple]
# 3                                                                                         nan
# 4                  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 5                 [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
# 6                                                                                         nan
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour...
# 8                   [Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 9         [Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 10                                                                                        nan
# 11     [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]
# 12                        [Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream]]
# 13             [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole]]
# 14                                                                                        nan
# 15                                                                                        nan
# 16                  [Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Cheese, Sour Cream]]
# 17              [Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]
# 18                                                                                   [Sprite]
# 19  [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettu...
#
#    item_price
# 0      $2.39
# 1      $3.39
# 2      $3.39
# 3      $2.39
# 4     $16.98
# 5     $10.98
# 6      $1.69
# 7     $11.75
# 8      $9.25
# 9      $9.25
# 10     $4.45
# 11     $8.75
# 12     $8.75
# 13    $11.25
# 14     $4.45
# 15     $2.39
# 16     $8.49
# 17     $8.49
# 18     $2.18
# 19     $8.75

# %%
#What is the total price for each order?

price_item = chipotle_df.item_price.str.replace('$', '').astype('float')
# Out:
# /var/folders/9q/slnrpghs0r78mkz6d7_q_hj40000gp/T/ipykernel_17903/987064685.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   price_item = chipotle_df.item_price.str.replace('$', '').astype('float')

# %%
chipotle_df.groupby('order_id')['item_price'].sum()
# Out:
# order_id
# 1       $2.39 $3.39 $3.39 $2.39
# 2                        $16.98
# 3                  $10.98 $1.69
# 4                  $11.75 $9.25
# 5                   $9.25 $4.45
# 6                   $8.75 $8.75
# 7                  $11.25 $4.45
# 8                   $2.39 $8.49
# 9                   $8.49 $2.18
# 10                  $8.75 $4.45
# 11                  $8.99 $3.39
# 12                 $10.98 $3.39
# 13                  $2.39 $8.49
# 14                  $8.99 $1.09
# 15                  $8.49 $2.39
# 16                  $8.99 $1.69
# 17                  $8.99 $1.09
# 18      $8.75 $8.75 $4.45 $2.95
# 19                 $11.75 $2.15
# 20    $4.45 $11.25 $11.75 $8.75
# 21           $10.98 $8.99 $3.39
# 22                  $8.99 $3.99
# 23                  $8.99 $2.18
# 24                 $10.98 $1.09
# 25                  $8.99 $2.39
# 26                 $9.25 $11.25
# 27                 $11.75 $2.15
# 28     $4.45 $9.25 $11.25 $8.75
# 29                  $8.99 $8.99
# 30           $3.39 $8.99 $10.98
# 31                  $8.99 $1.69
# 32                  $8.99 $3.99
# 33                  $8.75 $4.45
# 34      $8.75 $8.75 $2.15 $8.75
# 35                 $11.25 $2.15
# 36                  $9.25 $8.75
# 37                  $8.75 $9.25
# 38            $8.49 $8.99 $1.09
# 39                  $9.25 $2.95
# 40          $11.75 $11.75 $9.25
# 41                 $11.75 $4.45
# 42                  $9.25 $4.45
# 43                 $11.75 $8.75
# 44                        $8.75
# Name: item_price, dtype: object

# %%
#What are the most popular 3 items?

chipotle_df.groupby('item_name')['id'].count().nlargest(3)
chipotle_df.value_counts('item_name').head(3)
# Out:
# item_name
# Chicken Burrito        12
# Chips and Guacamole    11
# Steak Burrito          11
# dtype: int64

# %%
#Which item has produced the most revenue?

most_rev = chipotle_df.groupby('item_name')['item_price'].agg('sum')
most_rev
# Out:
# item_name
# Barbacoa Bowl                                                                                    $11.75 $11.75 $9.25
# Barbacoa Burrito                                                                                         $8.99 $9.25
# Barbacoa Soft Tacos                                                                                            $9.25
# Bottled Water                                                                                            $1.09 $1.09
# Canned Soda                                                                                  $2.18 $1.09 $2.18 $1.09
# Carnitas Bowl                                                                                           $8.99 $11.75
# Carnitas Burrito                                                                                  $8.99 $9.25 $11.75
# Chicken Bowl                                               $16.98 $10.98 $11.25 $8.75 $8.49 $11.25 $8.75 $8.75 $8.75
# Chicken Burrito                          $8.49 $8.49 $10.98 $8.49 $10.98 $10.98 $8.75 $10.98 $8.75 $8.75 $8.75 $8.75
# Chicken Crispy Tacos                                                                                           $8.75
# Chicken Salad Bowl                                                                                             $8.75
# Chicken Soft Tacos                                                                    $8.75 $8.75 $8.75 $8.75 $11.25
# Chips                                                                                        $2.15 $2.15 $2.15 $2.15
# Chips and Fresh Tomato Salsa                                                                 $2.39 $2.39 $2.39 $2.95
# Chips and Guacamole                                $4.45 $4.45 $4.45 $4.45 $4.45 $3.99 $4.45 $3.99 $4.45 $4.45 $4.45
# Chips and Tomatillo Green Chili Salsa                                                                          $2.95
# Chips and Tomatillo-Green Chili Salsa                                                              $2.39 $2.39 $2.39
# Izze                                                                                         $3.39 $3.39 $3.39 $3.39
# Nantucket Nectar                                                                                         $3.39 $3.39
# Side of Chips                                                                                      $1.69 $1.69 $1.69
# Steak Bowl                                                                                 $8.99 $8.99 $11.75 $11.75
# Steak Burrito                                    $11.75 $9.25 $8.99 $11.75 $8.99 $8.99 $8.99 $8.99 $8.99 $8.99 $8.99
# Steak Crispy Tacos                                                                                             $9.25
# Steak Soft Tacos                                                                             $9.25 $9.25 $8.99 $9.25
# Veggie Bowl                                                                                             $11.25 $8.49
# Veggie Burrito                                                                                                $11.25
# Name: item_price, dtype: object

# %%
#Join the employees and titles DataFrames together.

#employees_df.merge(titles_df, 
#            left_on='hire_date', 
#            right_on='emp_no', 
#            how='outer', 
#            indicator=True
#           )

employees_df.merge(titles_df,  on='emp_no')
# Out:
#     emp_no  birth_date  first_name    last_name gender   hire_date  \
# 0    10001  1953-09-02      Georgi      Facello      M  1986-06-26
# 1    10002  1964-06-02     Bezalel       Simmel      F  1985-11-21
# 2    10003  1959-12-03       Parto      Bamford      M  1986-08-28
# 3    10004  1954-05-01   Chirstian      Koblick      M  1986-12-01
# 4    10004  1954-05-01   Chirstian      Koblick      M  1986-12-01
# 5    10005  1955-01-21     Kyoichi     Maliniak      M  1989-09-12
# 6    10005  1955-01-21     Kyoichi     Maliniak      M  1989-09-12
# 7    10006  1953-04-20      Anneke      Preusig      F  1989-06-02
# 8    10007  1957-05-23     Tzvetan    Zielinski      F  1989-02-10
# 9    10007  1957-05-23     Tzvetan    Zielinski      F  1989-02-10
# 57            Engineer  1993-02-14  1999-02-14
# 58     Senior Engineer  1999-02-14  9999-01-01
# 59        Senior Staff  1998-11-12  9999-01-01
# 60               Staff  1989-11-12  1998-11-12
# 61        Senior Staff  2000-03-21  2000-08-10
# 62               Staff  1993-03-21  2000-03-21
# 63            Engineer  1990-10-20  1997-10-20
# 64     Senior Engineer  1997-10-20  9999-01-01
# 65    Technique Leader  1994-05-21  9999-01-01
# 66            Engineer  1996-11-16  9999-01-01
# 67        Senior Staff  2000-06-20  9999-01-01
# 68               Staff  1992-06-20  2000-06-20
# 69            Engineer  1989-03-31  1998-03-31
# 70     Senior Engineer  1998-03-31  9999-01-01
# 71            Engineer  1985-02-24  1987-01-27
# 72        Senior Staff  2000-05-04  9999-01-01
# 73               Staff  1992-05-04  2000-05-04
# 74        Senior Staff  1999-12-25  9999-01-01
# 75               Staff  1990-12-25  1999-12-25
# 76            Engineer  1992-10-15  1998-10-15
# 77     Senior Engineer  1998-10-15  9999-01-01
# 78        Senior Staff  2002-01-31  9999-01-01
# 79               Staff  1997-01-31  2002-01-31
# 80        Senior Staff  1994-11-13  9999-01-01
# 81        Senior Staff  2000-07-28  9999-01-01
# 82               Staff  1995-07-29  2000-07-28
# 83               Staff  1992-04-27  1995-07-22
# 84            Engineer  1990-02-01  1999-02-01
# 85     Senior Engineer  1999-02-01  9999-01-01
# 86            Engineer  1992-01-15  2000-01-15
# 87     Senior Engineer  2000-01-15  9999-01-01
# 88        Senior Staff  1988-04-25  9999-01-01
# 89        Senior Staff  1991-06-26  9999-01-01
# 90        Senior Staff  1996-05-28  9999-01-01
# 91               Staff  1989-05-28  1996-05-28
# 92        Senior Staff  1989-12-02  9999-01-01
# 93            Engineer  1991-08-30  1999-08-30
# 94     Senior Engineer  1999-08-30  9999-01-01
# 95     Senior Engineer  1989-04-08  9999-01-01
# 96               Staff  1985-11-20  1992-03-02
# 97            Engineer  1998-05-24  9999-01-01
# 98  Assistant Engineer  1986-02-26  1992-02-26
# 99            Engineer  1992-02-26  1998-02-25

# %%
#For each title, find the hire date of the employee that was hired most recently with that title.

emp_title = employees_df.merge(titles_df,  on='emp_no')

# %%
emp_title.groupby('title')['from_date'].agg('max')
# Out:
# title
# Assistant Engineer    1998-06-14
# Engineer              1999-09-27
# Senior Engineer       2001-04-01
# Senior Staff          2002-01-31
# Staff                 1999-04-30
# Technique Leader      1994-05-21
# Name: from_date, dtype: object

# %%
#Write the code necessary to create a cross tabulation of the number of titles by department. 
#(Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to 
#perform the manipulations.)


cross_query = '''
            SELECT. t.title,  d,dept_name
            FROM dept_emp
            JOIN titles t USING(dept_no)
            JOIN departments d USING(dept_no)
            WHERE t.to_date >. NOW();
            '''

# %%
cross_url = get_db_url(host, username, password, 'employees')

# %%
df_cross = pd.read_sql(cross_query, cross_url)
df_cross.head()

# %%
pd.crosstab(df_cross['title'],  df_cross['dept_name']).T
